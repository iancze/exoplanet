# %%
# %matplotlib inline

# %%
# %run notebook_setup
# Out:
# theano version: 1.0.3
# pymc3 version: 3.5
# exoplanet version: 0.1.5

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from astropy.time import Time
from astropy.io import ascii
from astropy import units as u

deg = np.pi/180.

# %% [markdown]
# # Astrometric Orbits with Exoplanet
#
# In this notebook we'll walk through the astrometric functionalities of `exoplanet` and how they can be used to fit a variety of systems, including those with parallax and radial velocity measurements.
#
# To start, we'll start with the simplest example (in terms of number of parameters), which is fitting an orbit of a binary star system that only has astrometric measurements of the separation and orientation of the two stars as a function of time.
#
# ## Data
# First, let's load and examine the data. We'll use the astrometric measurements of HR 466 (HD 10009) as compiled by [Pourbaix 1998](https://ui.adsabs.harvard.edu/#abs/1998A&AS..131..377P/abstract). The speckle observations are originally from [Hartkopf et al. 1996](https://ui.adsabs.harvard.edu/#abs/1996AJ....111..370H/abstract). There are also radial velocities from [Tokovinin 1993](https://ui.adsabs.harvard.edu/#abs/1993AstL...19...73T/abstract), which we'll use later on. We'll follow the conventions from Pourbaix et al., which are a consistent set conforming to the right-hand-rule and the conventions of the visual binary field, where the ascending node is that where the secondary is *receeding* from the observer.

# %%
# grab the formatted data and do some munging
astro_url = "https://gist.github.com/iancze/262aba2429cb9aee3fd5b5e1a4582d4d/raw/c5fa5bc39fec90d2cc2e736eed479099e3e598e3/astro.txt"
rv1_url = "https://gist.github.com/iancze/262aba2429cb9aee3fd5b5e1a4582d4d/raw/c5fa5bc39fec90d2cc2e736eed479099e3e598e3/rv1.txt"
rv2_url = "https://gist.github.com/iancze/262aba2429cb9aee3fd5b5e1a4582d4d/raw/c5fa5bc39fec90d2cc2e736eed479099e3e598e3/rv2.txt"

astro_data_full = ascii.read(astro_url, format="csv", fill_values=[(".", '0')])

# %%
# convert UT date to JD
astro_dates = Time(astro_data_full["date"].data, format="decimalyear")

# Following the Pourbaix et al. 1998 analysis, we'll limit ourselves to the following highest quality data
# since the raw collection of data outside of these ranges has some ambiguities in swapping 
# the primary and secondary star
ind = (astro_dates.value > 1975.) & (astro_dates.value < 1999.73)

astro_data = astro_data_full[ind]

astro_yrs = astro_data["date"]
astro_dates.format = 'jd'
astro_jds = astro_dates[ind].value

rho_data = astro_data["rho"]
rho_err = astro_data["rho_err"]

theta_data = astro_data["PA"]
theta_err = astro_data["PA_err"]
# Out:
# WARNING: ErfaWarning: ERFA function "dtf2d" yielded 6 of "dubious year (Note 6)" [astropy._erfa.core]
# WARNING: ErfaWarning: ERFA function "dtf2d" yielded 5 of "dubious year (Note 6)" [astropy._erfa.core]
# WARNING: ErfaWarning: ERFA function "utctai" yielded 5 of "dubious year (Note 3)" [astropy._erfa.core]
# WARNING: ErfaWarning: ERFA function "utctai" yielded 6 of "dubious year (Note 3)" [astropy._erfa.core]
# WARNING: ErfaWarning: ERFA function "taiutc" yielded 6 of "dubious year (Note 4)" [astropy._erfa.core]
# WARNING: ErfaWarning: ERFA function "d2dtf" yielded 6 of "dubious year (Note 5)" [astropy._erfa.core]

# %% [markdown]
# Many of these measurements do not have associated error measurements. For these, we assume a modest estimate of $1^\circ$ in position angle and $0.01"$ in separation to get a preliminary fit. The scatter in points around the final solution will be a decent guide of what the systematics in the measurement uncertainty actually were.

# %%
astro_data["PA_err"][astro_data["PA_err"].mask == True] = 1.0

# %%
astro_data["rho_err"][astro_data["rho_err"].mask == True] = 0.01

# %%
theta_data = astro_data["PA"]
theta_err = astro_data["PA_err"]

rho_data = astro_data["rho"]
rho_err = astro_data["rho_err"]

# and here is the full table
astro_data
# Out:
# <Table masked=True length=38>
#    date      PA    PA_err   rho   rho_err
#  float64  float64 float64 float64 float64
# --------- ------- ------- ------- -------
# 1976.8571   139.1     0.5   0.168   0.004
# 1976.9226   139.6     0.3   0.171   0.001
# 1977.6352   134.8     1.0    0.15    0.01
# 1977.7335   136.5     0.4   0.147   0.009
# 1977.9164   130.5     1.0   0.125    0.01
# 1978.6154   128.3     1.0   0.108   0.009
# 1979.7731   124.0     1.0   0.102    0.01
# 1980.7179   106.0     1.0   0.075    0.01
# 1982.7657    57.8     1.0   0.061    0.01
#  1982.852    66.7     6.5   0.091    0.01
#       ...     ...     ...     ...     ...
# 1994.7085   154.5     1.0   0.291    0.01
# 1995.9182   153.3     1.0   0.296    0.01
#  1996.694   154.3     1.0     0.3    0.01
# 1997.8241   153.3     1.0   0.291    0.01
# 1997.8296      --     1.0      --    0.01
# 1997.8296   151.2     1.0   0.298    0.01
# 1998.7773      --     1.0      --    0.01
# 1998.7773   151.0     0.5   0.285   0.002
# 1999.7228   149.0     1.0   0.288    0.01
# 1999.7258   148.9     1.0   0.282    0.01

# %%
# normally, we assume that rho is measured in degrees east of north

# Make a plot of the astrometric data on the sky

fig, ax = plt.subplots(nrows=1)

xs = rho_data * np.cos(theta_data * deg) # X is north
ys = rho_data * np.sin(theta_data * deg) # Y is east
ax.plot(ys, xs, ".")
ax.set_ylabel(r"$\Delta \delta$ ['']")
ax.set_xlabel(r"$\Delta \alpha \cos \delta$ ['']")
ax.invert_xaxis()
ax.plot(0,0, "k*")
ax.set_aspect("equal", "datalim")

# %% [markdown]
# The plot on the sky makes the most sense for interpreting the physical scale of the orbit, but when traditional astrometric measurements are made of a secondary star, they are usually made as the separation and angle from the primary star. This means that the "raw" measurements are the values of $\rho$ (separation) and P.A. (position angle) that we listed in our data table, and that the measurement uncertainties live on these values as nice Gaussians. So, to visualize this space more clearly, we can plot $\rho$ vs. time and P.A. vs. time.

# %%
fig, ax = plt.subplots(nrows=2, sharex=True)
ax[0].plot(astro_yrs, rho_data, ".")
ax[0].errorbar(astro_yrs, rho_data, yerr=rho_err, ls="")
ax[0].set_ylabel(r'$\rho\,$ ["]')

ax[1].plot(astro_yrs, theta_data, ".")
ax[1].errorbar(astro_yrs, theta_data, yerr=theta_err, ls="")
ax[1].set_ylabel(r'P.A. [degrees]');
# Out:
# /Users/ianczekala/.build/miniconda3/lib/python3.7/site-packages/numpy/core/numeric.py:501: UserWarning: Warning: converting a masked element to nan.
#   return array(a, dtype, copy=False, order=order)

# %%
# this is the way the orbit is plotted in Hartkopf et al. 1996

# fig, ax = plt.subplots(nrows=1)

# xs = rho_data * np.cos(theta_data * deg) # X is north
# ys = rho_data * np.sin(theta_data * deg) # Y is east
# ax.plot(ys[ind], xs[ind], ".")
# ax.set_ylabel(r"$\Delta \delta$ ['']")
# ax.set_xlabel(r"$\Delta \alpha \cos \delta$ ['']")
# ax.invert_yaxis()
# ax.plot(0,0, "k*")
# ax.set_aspect("equal", "datalim")

# %%
import pymc3 as pm 
import theano.tensor as tt

import exoplanet as xo

import exoplanet.orbits
import exoplanet.orbits.astrometric as astro
from exoplanet.distributions import Angle

# %% [markdown]
# The key is to solve the transcendental Kepler equation
#
# $$
# M = E - e \sin E
# $$
#
# The mean angular motion is
#
# $$
# n = \frac{2 \pi}{P}
# $$
#
# Throughout, `exoplanet` uses the convention where the reference epoch $t_0$ corresponds to a *transit*, and the mean anomaly $M$ is calculated relative to this.
#
# Since we don't have a transiting system, we would like to refer this to time of pericenter passage. Wikipedia has the helpful formula
#
# $$
# M = M_0 + n(t - t_0)
# $$
#
# `exoplanet` uses the starting guess of
#
# $$
# M_0 = E_0 - e \sin(E_0)
# $$
#
# and then calculates a reference time
#
# $$
# t_\mathrm{ref} = t_0 - \frac{M_0}{n}
# $$
#
#
# It's not really clear what this reference time is, but I think it is time of periastron.
#
# To correspond to epoch of periastron, we need to set
#
# $$
# t_\mathrm{ref} = t_0
# $$
#
# and calculate
#
# $$
# M = (t - t_\mathrm{ref}){n}
# $$
#
# In the RV example, DFM fits for a phase $\phi$, and then calculates
#
# $$
# t_0 = \frac{\phi + \omega}{n}
# $$
#
# so,
#
# $$
# \phi = t_0 n - \omega
# $$
#
# mean anomaly is calculated as
#
# $$
# M = nt - (\phi + \omega)
# $$

# %%
# Just to get started, let's take a look at the orbit using the best-fit parameters from Pourbaix et al. 1998

# Orbital elements from Pourbaix et al. 1998
# For the relative astrometric fit, we only need the following parameters
a = 0.324 # arcsec
e = 0.798
# e = 0.3
i = 96.0 * deg # [rad]
omega = 251.6 * deg # omega_2 according to Pourbaix RV equations
Omega = 159.6 * deg 
P = 28.8 * 365.25 # days

T0 = Time(1989.92, format="decimalyear")
T0.format = "jd"
T0 = T0.value # [Julian Date]
# T0 = 1989.92 # yr
# T0 = T0 - 0.25 * P

# n = 2 * np.pi / P
# t0 = (phi + w) / n

# instantiate the orbit
orbit = astro.AstrometricOrbit(a_ang=a, t0=T0, period=P, incl=i, ecc=e, omega=omega, Omega=Omega)

# make a theano function to get stuff from orbit 
times = tt.vector("times")
ang = orbit.get_relative_position(times) # the rho, theta measurements
pos = orbit.get_relative_position_XY(times) # the Dec, RA measurements
anom = orbit._get_true_anomaly(times)


f_anom = theano.function([times], anom)
f_ang = theano.function([times], ang)
f_pos = theano.function([times], pos)

t = np.linspace(T0 - P, T0 + P, num=200) # days

anoms = f_anom(t)
rho, theta = f_ang(t)
X, Y = f_pos(t)

# %%
from scipy.optimize import fsolve

def theta(t):
    '''Calculate the true anomoly for the A-B orbit.
    Input is in days.'''

    # t is input in seconds

    # Take a modulus of the period
    t = (t - T0) % P
#     t = (t - orbit.tref.eval()) % P

    f = lambda E: E - e * np.sin(E) - 2 * np.pi * t/P
    E0 = 2 * np.pi * t / P

    E = fsolve(f, E0)[0]

    th = 2 * np.arctan(np.sqrt((1 + e)/(1 - e)) * np.tan(E/2.))

    if E < np.pi:
        return th
    else:
        return th + 2 * np.pi

# %%
calc_anom = [theta(x) for x in t]

# %%
plt.plot(t, calc_anom, label="PSOAP")
plt.plot(t, anoms, label="exoplanet")
plt.legend()

# %%
rho

# %%
fig, ax = plt.subplots(nrows=2, sharex=True)
ax[0].plot(t, rho)
ax[0].plot(astro_jds, rho_data, ".")
ax[0].errorbar(astro_jds, rho_data, yerr=rho_err, ls="")
ax[0].set_ylabel(r'$\rho\,$ ["]')

theta_wrap = theta 
theta_wrap[theta_wrap < 0] += 2 * np.pi

ax[1].plot(t, theta * 180/np.pi)
ax[1].plot(astro_jds, theta_data, ".")
ax[1].errorbar(astro_jds, theta_data, yerr=theta_err, ls="")
ax[1].set_ylabel(r'P.A. [degrees]');

# %%
fig, ax = plt.subplots(nrows=1)
ax.plot(Y, X, "o")
ax.plot(0, 0, "k*")
ax.invert_xaxis()
ax.set_xlabel(r"$\Delta \alpha \cos \delta$ [arcsec]")
ax.set_ylabel(r"$\Delta \delta$ [arcsec]");
ax.set_aspect("equal", "datalim")

# %% [markdown]
# Orbit fitting tip from Mike Fitzgerald to use $\Omega+\omega$ and $\Omega-\omega$ for fitting, since you can get unambiguous constraints on those parameters.

# %% [markdown]
# Without radial velocity information, there is a $180^\circ$ degeneracy in the position angle of the ascending node, $\Omega_2$.

# %%
28.8 * 365.25
# Out:
# 10519.2

# %%
# Sample the orbit 

with pm.Model() as model:
    
    a = pm.Uniform("a", lower=0.1, upper=1.0) # arcsec
    logP = pm.Uniform("logP", lower=9, upper=11, testval=np.log(28.8 * 365.25))
    
    omega = Angle("omega")
    Omega = Angle("Omega")
    phi = Angle("phi")
    incl = pm.Uniform("incl", lower=0, upper=np.pi) # radians
    e = pm.Uniform("e", lower=0.0, upper=1.0, testval=0.1)
    
    # Deterministic transformations
    n = 2*np.pi*tt.exp(-logP)
    P = pm.Deterministic("P", tt.exp(logP))
    T0 = (phi + omega) / n # calculate epoch of periastron for initialization

    # The RV model
    # M = n * t - (phi + w)
    
    orbit = astro.AstrometricOrbit(a_ang=a, t0=T0, period=P, incl=incl, ecc=e, omega=omega, Omega=Omega)
    
    rho_model, theta_model = orbit.get_relative_position(astro_jds) # the rho, theta measurements
    
    pm.Normal("obs_rho", mu=rho_model, observed=np.array(rho_data.data.data), sd=np.array(rho_err.data.data))
    pm.Normal("obs_theta", mu=theta_model, observed=np.array(theta_data.data.data) * deg, sd=np.array(theta_err.data.data) * deg)

# %%
with model:
    trace = pm.sample(draws=2000, tune=1000, chains=2)
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (2 chains in 4 jobs)
# NUTS: [e, incl, phi, Omega, omega, logP, a]
# Sampling 2 chains:  12%|█▏        | 714/6000 [00:01<00:10, 501.91draws/s]
# ---------------------------------------------------------------------------
# RemoteTraceback                           Traceback (most recent call last)
# RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "/Users/ianczekala/.build/miniconda3/lib/python3.7/site-packages/pymc3/parallel_sampling.py", line 73, in run
#     self._start_loop()
#   File "/Users/ianczekala/.build/miniconda3/lib/python3.7/site-packages/pymc3/parallel_sampling.py", line 113, in _start_loop
#     point, stats = self._compute_point()
#   File "/Users/ianczekala/.build/miniconda3/lib/python3.7/site-packages/pymc3/parallel_sampling.py", line 139, in _compute_point
#     point, stats = self._step_method.step(self._point)
#   File "/Users/ianczekala/.build/miniconda3/lib/python3.7/site-packages/pymc3/step_methods/arraystep.py", line 247, in step
#     apoint, stats = self.astep(array)
#   File "/Users/ianczekala/.build/miniconda3/lib/python3.7/site-packages/pymc3/step_methods/hmc/base_hmc.py", line 115, in astep
#     self.potential.raise_ok(self._logp_dlogp_func._ordering.vmap)
#   File "/Users/ianczekala/.build/miniconda3/lib/python3.7/site-packages/pymc3/step_methods/hmc/quadpotential.py", line 201, in raise_ok
#     raise ValueError('\n'.join(errmsg))
# ValueError: Mass matrix contains zeros on the diagonal.
# The derivative of RV `e_interval__`.ravel()[0] is zero.
# The derivative of RV `incl_interval__`.ravel()[0] is zero.
# The derivative of RV `phi_angle__`.ravel()[0] is zero.
# The derivative of RV `phi_angle__`.ravel()[1] is zero.
# The derivative of RV `Omega_angle__`.ravel()[0] is zero.
# The derivative of RV `Omega_angle__`.ravel()[1] is zero.
# The derivative of RV `omega_angle__`.ravel()[0] is zero.
# The derivative of RV `omega_angle__`.ravel()[1] is zero.
# The derivative of RV `a_interval__`.ravel()[0] is zero.
# """
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# ValueError: Mass matrix contains zeros on the diagonal.
# The derivative of RV `e_interval__`.ravel()[0] is zero.
# The derivative of RV `incl_interval__`.ravel()[0] is zero.
# The derivative of RV `phi_angle__`.ravel()[0] is zero.
# The derivative of RV `phi_angle__`.ravel()[1] is zero.
# The derivative of RV `Omega_angle__`.ravel()[0] is zero.
# The derivative of RV `Omega_angle__`.ravel()[1] is zero.
# The derivative of RV `omega_angle__`.ravel()[0] is zero.
# The derivative of RV `omega_angle__`.ravel()[1] is zero.
# The derivative of RV `a_interval__`.ravel()[0] is zero.
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-28-e690ae913e91> in <module>
#       1 with model:
# ----> 2     trace = pm.sample(draws=2000, tune=1000, chains=2)
#
# ~/.build/miniconda3/lib/python3.7/site-packages/pymc3/sampling.py in sample(draws, step, init, n_init, start, trace, chain_idx, chains, cores, tune, nuts_kwargs, step_kwargs, progressbar, model, random_seed, live_plot, discard_tuned_samples, live_plot_kwargs, compute_convergence_checks, use_mmap, **kwargs)
#     447             _print_step_hierarchy(step)
#     448             try:
# --> 449                 trace = _mp_sample(**sample_args)
#     450             except pickle.PickleError:
#     451                 _log.warning("Could not pickle model, sampling singlethreaded.")
#
# ~/.build/miniconda3/lib/python3.7/site-packages/pymc3/sampling.py in _mp_sample(draws, tune, step, chains, cores, chain, random_seed, start, progressbar, trace, model, use_mmap, **kwargs)
#     997         try:
#     998             with sampler:
# --> 999                 for draw in sampler:
#    1000                     trace = traces[draw.chain - chain]
#    1001                     if trace.supports_sampler_stats and draw.stats is not None:
#
# ~/.build/miniconda3/lib/python3.7/site-packages/pymc3/parallel_sampling.py in __iter__(self)
#     303
#     304         while self._active:
# --> 305             draw = ProcessAdapter.recv_draw(self._active)
#     306             proc, is_last, draw, tuning, stats, warns = draw
#     307             if self._progress is not None:
#
# ~/.build/miniconda3/lib/python3.7/site-packages/pymc3/parallel_sampling.py in recv_draw(processes, timeout)
#     221         if msg[0] == 'error':
#     222             old = msg[1]
# --> 223             six.raise_from(RuntimeError('Chain %s failed.' % proc.chain), old)
#     224         elif msg[0] == 'writing_done':
#     225             proc._readable = True
#
# ~/.build/miniconda3/lib/python3.7/site-packages/six.py in raise_from(value, from_value)
#
# RuntimeError: Chain 0 failed.

# %%
pm.traceplot(trace)
# Out:
# /Users/ianczekala/.build/miniconda3/lib/python3.7/site-packages/matplotlib/axes/_base.py:3604: MatplotlibDeprecationWarning:
# The `ymin` argument was deprecated in Matplotlib 3.0 and will be removed in 3.2. Use `bottom` instead.
#   alternative='`bottom`', obj_type='argument')
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1c269e18d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1c26e56908>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1c26e2cd30>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1c26e53f60>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1c26d721d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1c26d70400>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1c26eab630>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1c281dd668>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1c281d3a90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1c2697acc0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1c26732ef0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1c26745160>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1c26d05390>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1c272d45c0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1c272c97f0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1c26f0da20>]],
#       dtype=object)
